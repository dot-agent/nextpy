# %%
import nextpy.interfaces.jupyter as xtj
import pandas as pd
import plotly.express as px
import datetime
import reacton.ipyvuetify as v

image_path = 'C:/Users/HP/Documents/New_Nextpy_Development/nextpy/interfaces/jupyter/components/media/scene.jpg'
img = xtj.image(image_path, width="50%")
text_area = xtj.textarea(
    label=None,
    placeholder="Enter text here...",
    style='border: 1px solid #CCC; border-radius: 5px;',
)
color_picker = xtj.color_picker(
        label="Pick A Color",
        value="#00f900",  
        help="Choose a color from the picker",  
        on_change=None,  
        args=None,  
        kwargs=None,  
        disabled=False,  
        label_visibility="visible"  
    )

date_picker_instance = xtj.date_picker(
    label=None,
    min="2000-01-01",
    max="2030-12-31",
    value=None  
)

time_input_instance = xtj.time_picker(
        label="Select Time",
        value=datetime.time(10, 30),  
        style='color: blue;',         
        
    )
options = ["Comedy", "Drama", "Documentary"]
icons = ["", "", "🎥"]  

genre_radio = xtj.radio(
    label="What's your favorite movie genre",
    options=options,
    value=options[2],  
    icons=icons,       
    horizontal=False,  
    class_name='',     
    style='',          
)

df_example = pd.DataFrame({
    'Column 1': [1, 2, 3, 4],
    'Column 2': [5, 6, 7, 8],
    'Column 3': ['A', 'B', 'C', 'D']
})
dataframe_instance = xtj.dataframe(df_example, width=500, height=300, use_container_width=True)

metric_card_1 = xtj.metrics(label="Temperature", value="70 °F", delta="1.2 °F")
metric_card_2 = xtj.metrics(label="Wind", value="9 mph", delta="-8 %")
metric_card_3 = xtj.metrics(label="Humidity", value="86 %", delta="4 %")
example_json_data = {
    "user": {
        "name": "Jane Smith",
        "id": 102,
        "permissions": ["admin", "editor"]
    },
    "settings": {
        "theme": "dark",
        "notifications": {
            "email": True,
            "sms": False
        }
    }
}

json_display_component = xtj.json_display(example_json_data, expanded=False)
    

@xtj.component
def Page():
    xtj.title('Testing')   
    xtj.dataframe(df_example, width=500, height=300, use_container_width=True)
    display(dataframe_instance)
    display(metric_card_1)
    display(metric_card_2)
    display(metric_card_3)
    display(json_display_component)
    
Page()
# Out:
# Compiling takes time, but the compiled app is super fast⚡:
# 😂['hip', 'hip'] (hip hip array!) 😂
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import nextpy.interfaces.jupyter as xtj
#       2 import pandas as pd
#       3 import plotly.express as px
#
# File D:\Dotagent\nextpy\nextpy\interfaces\jupyter\__init__.py:54
#      52 from .cache import memoize
#      53 from . import cache
# ---> 54 from .components import *
#      55 from .state import State
#      56 from .routing import use_route, use_router, use_route_level, find_route, use_pathname, resolve_path
#
# File D:\Dotagent\nextpy\nextpy\interfaces\jupyter\components\__init__.py:11
#       9 from .control import form
#      10 from .data_elements import dataframe, metrics, json_display
# ---> 11 from .input_widgets import button, download_button, link_button
#      12 from .input_widgets import checkbox, select_box, multiselect, radio, switch
#      13 from .input_widgets import select_slider, select_slider_float
#
# File D:\Dotagent\nextpy\nextpy\interfaces\jupyter\components\input_widgets\__init__.py:6
#       4 from .date_picker import date_picker
#       5 from .download_button import download_button
# ----> 6 from .file_browser import file_browser
#       7 from .file_uploader import file_dropper
#       8 from .input import input
#
# File D:\Dotagent\nextpy\nextpy\interfaces\jupyter\components\input_widgets\file_browser.py:6
#       3 from pathlib import Path
#       4 from typing import Callable, List, Optional, Union, cast
# ----> 6 import humanize
#       7 import ipyvuetify as vy
#       8 import traitlets
#
# ModuleNotFoundError: No module named 'humanize'
